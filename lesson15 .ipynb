# %% [markdown]
# # LanguageStudyAttendant
# ## LanguageStudyAttendant项目市场分析：
#
# ### 一、 在线语言学习市场调研与分析
# 市场概况（2024年）
# • 市场规模： 预计达到 1852 亿美元
# • 用户数量：每用户平均收入 (ARPU) 预计为 210 美元/用户，用户渗透率 为 14.9%
# • 地区对比：美国最大市场，中国增长最快。
# 增长预测（2029年）
# • 市场规模： 预计将达到 2793亿美元
# • 用户数量： 预计用户数达 11.21亿，用户渗透率 22.5%
# • 复合年均增长率 (CAGR，Compound Annu为8.56% 。
#
# 为e)预计。。
#  ### 二、 在线教育市场:市场规模和用户增长分析育市场：市场规
# 市场规模与增长预估
# • 2023年：140-160 亿美元 / 1852 亿美元
# • 2030年：400-520 亿美元 / 2793亿美元
# • 占比：85%5%.1% -> 16.5% 。
# 复合年均增长率（CAGR）
# • 语言学习市场：18-20%。
# • 市场平均值： 8.56% 。
#
# ### 三、 在线语言学习市场：规模占比与增长趋势分析场
# 英语需求最大(需求量从大到小排序：英语、汉语、西班牙语、法语、德语、日语)
#
# ### 四、 全球语言学习增长最快地区
# 亚太地区:
# • 贡献全球市场增长的 43%
# • 主要语言包括 英语、普通话、日语 和 韩语
# • 经济扩张和国际业务的需求推动了语言
# • 北美:
# • 企业对语言技能的需求不断增加
# • 主要学习语言包括 西班牙语、法语、德语 和 手语
# • 技术进步和 AI 助力的语言学习推市场增长
# • 欧洲:
# • 对多语言技能的高需求
# • 主要语言为 英语、法语、西班牙语、德语 和 意大利语
# • 高互联网普及率和在线平台推动市场发展
# • 拉丁美洲:
# • 对 英语 的需求持续上升
# • 其他需求语言包括 葡萄牙语 和 西班牙语
# • 数字基
#
# ### 五、 现有服
# 务模式：私教、小班授课、在线学习
# #### 市场上的产品：础服务模式	特点	典型平台
# 自学模式	学习者按照自己的节奏进行学习，内容多为视频、音频等格式	Duolingo, Babbel,Busuu
# 一对一在线辅导	学习者与教师一对一互动，提供个性化课程和反馈	iTalki, Preply, VIPKid
# 小班授课	多个学习者与教师互动，模拟线下课堂场景	Verbling, Cambly
# AI 辅助学习	利用人工智能提供个性化推荐、语音识别和智能对话	Speak, Mondly,Duolingo
# 混合学习模式	自学结合教师辅导，提供结构化学习路径	Rosetta Stone, EF,Education First
# 游戏化学习	通过游戏元素增加学习趣味性，利用奖励机制激励学习者	Duolingo, Lingodeer
# 企业培训模式	针对企业设计的语言培训服务，满足工作中的沟通需求	EF Corporate,Solutions, Rosetta,Stone for Business
# 语言交换	学习者与母语者进行语言互换学习，通过社交平台或应用实现	Tandem, HelloTalk
# MOOC	提供由大学或知名机构设计的语言课程，适合大量学习者	Coursera,se,Drops
# edX
# 移动应用	专为移动设备设计，学习者可以通过手机随时学习	Memri教#### 服务模式总结：
# 分类	服务模式	描述
# 私教	一对一在线辅导	通过视频或语音与真人教师一对一学习，提供个性化的课程和即时反馈。
# 小班授课	小班授课	多个学习者通过视频会议与教师互动，模拟线下语言课堂。
# 	企业培训模式	针对企业需求设计的定制语言课程，帮助员工提升语言能力。
# 在线学习	AI 辅助学习	借助人工智能技术，平台提供个性化推荐、智能对话练习和语音识别。
# 	自学模式	学习者按照自己的节奏和时间安排学习课程，通常以视频、音频等形式提供。
# 	混合学习模式	结合自学与真人教师辅导，提供结构化学习路径和教师监督。
# 	游戏化学习	通过游戏元素增加学习的趣味性和参与度，使用奖励机制、关卡挑战等激励学习。
# 	语言交换	学习者与不同国家的母语者进行语言互换，增强口语和听力能力。
# 	MOOC	通过开放课程平台提供的大规模语言课程，适合大量学习者。
# 	移动应用	通过手机应用随时随地学习，适
#
# ### 六、 现有收费模式： 按小时、按课程、订阅制
# #### 按小时收费 (Pay-per-hour)
# • 特点：这种模式通常用于一对一或小班授课的辅导服务，学习者根据实际参与的课程时长来支付费用，
# 通常是按小时计费。
# • 适用平台：
# • iTalki、Preply、Cambly。
# • 典型用户：
# • 希望获得定期辅导、并有具体学习目标的用户，如备考语言考试的学生或想提升口语水平的职场
# 人士。
# • 优势：
# • 灵活性强，学习者可以根据自己的时间和需求选择合适的时长。
# ，特别是如果需要长期学习。 适合需要个性化辅导的学习者，尤其是需要与真人教师互动的学习者。
# • 劣势：
# • 长期来看，按小时收费可能较为昂贵，特
# #### 按课程收费 (Pay-per-course)
# • 特点：学习者一次性支付某个完整课程的费用，通常该课程包含多个模块或单元，可以在特定时间内
# 或根据学习者的进度完成。
# • 适用平台：
# • Coursera、edX、Rosetta Stone。
# • 典型用户：
# • 有明确学习目标，喜欢按照固定计划或大纲完成学习的用户，例如想要从基础到高级逐步学习语
# 言的人。
# • 优势：
# • 结构化的课程学习体验，适合那些想要系统性学标，适合有自律性的人。
#
# 某一语言的人群。
# • 一次性支付整个课程费用，通常会比按小时收费更经济。
# • 劣势：
# • 灵活性相对较低，学习者必须完成整个课程才能达到目标#### 订阅制 (Subscription-based)
# • 特点：学习者按月或按年支付订阅费用，在订阅期内可以访问平台上所有的学习资源和课程。常见的
# 形式包括按月订阅、季度订阅或年度订阅。
# • 适用平台：
# • Duolingo Plus、Babbel、Busuu、Memrise。
# • 典型用户：
# • 想要长期提升语言能力，喜欢不断学习和探索新内容的用户，特别是那些需要灵活安排时间的学
# 习者。
# • 优势：
# • 学习者可以根据需要访问平台的所有课程和内容，具有较高的灵活性。
# • 适资源，可能浪费资金。
# 长期学习#者，且相对于按小时• 按小时收费：适合那些需要定期辅导或与教师互动的学习者，适合希望在短时间内提升语言水平的人。
# • 按课程收费：则更加适合那些有明确学习目标并喜欢系统化学习的人，通常用于完成一个完整的语言学习路径。
# • 订阅制：适合长期学习者，尤其是那些想要灵活安排学习时间并不断探索新内容的人。
# ### 七、 AI怎么切入、产品如何设计及
# • 产品设计：参考 Hi Echo 的探索体验和功能简化
# • 核心功能：对话训练和场景式体验
# • 用户分级：学习路径与产品功能的组合
# LanguageStudyAttendanttor 技术方案
# • Agent 核心技术：Cha（LCEL）tBot + Contextual Proario
# • Agent 应用技术： Lang（LCEL）chain + Ollama + Gradio GUI：ChatBot + Contextual Prompt + Customization- Scenario
# • Agent 应用技术： Langchain + Ollama +
#  Gradio GUI

# %%
#安装以下依赖
'''
langchain==0.2.16
langchain_core==0.2.41
langchain_community==0.2.17
langchain_openai==0.1.25
langchain_ollama==0.1.3
gradio==4.43.0
loguru==0.7.2
'''

# %% [markdown]
# Langchain Expression Language（LCEL）快速入门
# LCEL 是 LangChain 中的一个重要概念，LCEL是一种声明式的链式组合语言。它提供了一种统一的接口，允许不同的组件（如 retriever, prompt, llm 等）可以通过统一的 Runnable 接口连接起来。每个 Runnable 组件都实现了相同的方法，如 .invoke()、.stream() 或 .batch()，这使得它们可以通过 | 操作符轻松连接。
#
# LCEL 的优势
# LCEL使得从基本组件构建复杂链变得容易，并支持流式处理、并行处理和日志记录等开箱即用的功能。
#
# 统一接口: LCEL 通过 Runnable 接口将不同的组件统一起来，简化了复杂操作的实现。
# 模块化: 各个组件可以独立开发和测试，然后通过 LCEL 轻松集成。
# 可扩展性: LCEL 支持异步调用、批处理和流式处理，适应
#
# Agents：
# Agents 允许LLM自主完成任务。 Agents会决定采取哪些行动，然后执行该行动，并观察结果，并重复此过程直到任务完成。 LangChain为代理提供了标准接口、可选择的代理列表以及端到端代理示例。不同的应用场景。

# %% [markdown]
# 使用 LCEL 实现 LLMChain（Prompt + LLM)
# Pipe 管道操作符
# 我们使用LCEL的 | 操作符将这些不同组件拼接成一个单一链。
#
# 在这个链中，用户输入被传递到提示模板，然后提示模板的输出被传递到模型，接着模型的输出被传递到输出解析器。
#
# chain = prompt | model | output_parser
# 竖线符号类似于Unix管道操作符，它将不同的组件链接在一起，将一个组件的输出作为下一个组件的输入。

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# 初始化 ChatOpenAI 模型，指定使用的模型为 'gpt-4o-mini'
model = ChatOpenAI(model="gpt-4o-mini")

# 创建一个聊天提示模板，设置模板内容为"讲个关于 {topic} 的笑话吧"
prompt = ChatPromptTemplate.from_template("讲个关于 {topic} 的笑话吧")

# 初始化输出解析器，用于将模型的输出转换为字符串
output_parser = StrOutputParser()

# 构建一个处理链，先通过提示模板生成完整的输入，然后通过模型处理，最后解析输出
chain = prompt | model | output_parser

# 调用处理链，传入主题为"程序员"，生成关于程序员的笑话
chain.invoke({"topic": "程序员"})

# %%
核心概念：invoke 方法
Langchain invoke 方法是 LCEL 设计中的重要方法，可以帮助开发者更高效地处理复杂任务，结合语言模型进行系统构建，实现不同数据源和API的接口对接。

基础概念
在Langchain中，invoke方法是所有LangChain表达式语言（LCEL）对象的通用同步调用方法。通过invoke方法，开发者可以直接调用LLM或ChatModel，简化了调用流程，提高了开发效率。
与其他链式调用方法相比，invoke方法更加灵活便捷，可以直接对输入进行调用，而不需要额外的链式操作。相对于batch和stream等异步方法，invoke方法更适用于单一操作的执行。
使用方式
单次调用：通过invoke方法，开发者可以快速对单一操作进行执行，例如转换ChatMessage为Python字符串等简单操作，提升了代码的可读性和整洁度。
复杂协作：Langchain的核心理念就是将语言模型作为协作工具，invoke方法可以很好地实现开发者与语言模型的高效互动，构建出处理复杂任务的系统，并对接不同的数据源和API接口。
invoke 与 Model I/O 的结合
整个流程按照以下步骤进行：

Prompt 组件接收用户输入 **{"topic": "程序员"}**，然后使用该 topic 构建 PromptValue
Model 组件获取生成的提示，并传递给 GPT-3.5-Turbo 模型进行评估。从模型生成的输出是一个ChatMessage对象。
最后，output_parser 组件接收ChatMessage，并将其转换为Python字符串，在invoke方法中返回。
Prompt
prompt 是 BasePromptTemplate 的实例，这意味着它接受模板变量的字典并生成一个PromptValue。

PromptValue是一个包装器(wrapper)，围绕完成的提示进行操作，可以传递给LLM（以字符串作为输入）或ChatModel（以消息序列作为输入）。

它可以与任何语言模型类型一起使用，因为它定义了生成BaseMessages和生成字符串的逻辑。

from langchain import PromptTemplate

# Prompt 非 LCEL 使用方法
prompt_template = PromptTemplate.from_template(
    "讲个关于 {topic} 的笑话吧"
)

# 使用 format 生成提示
prompt = prompt_template.format(topic="程序员")
print(prompt)

# %%
#Agent 核心及架构技术：ChatBot 设计
class ConversationAgent:
'''
对话代理类，负责处理与用户的对话。
'''
    definit (self):
        self.name ="Conversation Agent"#代理名称
        # 读取系统提示语，从文件中加载
        with open("prompts/conversation prompt.txt""r',encoding='utf-8")as file:
            self.system_prompt = file.read().strip()
        # 创建聊天提示模板，包括系统提示和消息占位符
        self.prompt =ChatPromptTemplate.from_messages([
            ("system",self.system prompt), # 系统提示部分
            MessagesPlaceholder(variable_name="messages") # 消息占位符
        ])
        # 初始化 Chatollama 模型、配置模型参数
        self.chatbot= self.prompt | ChatOllama(
            model='llama3.1:8b-instruct-g8',# 使用的模型名称
            max_tokens=8192,# 最大生成的token数
            temperature=0.8,# 生成文本的随机性
        )

# %%
#Agent 核心技术：ChatBot + History
from langchain_core.chat_history import (
    BaseChatMessageHistory,  # 基础聊天消息历史类
    InMemoryChatMessageHistory,  # 内存中的聊天消息历史类
)


# 用于存储会话历史的字典
store = {}

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    """
    获取指定会话ID的聊天历史。如果该会话ID不存在，则创建一个新的聊天历史实例。
    
    参数:
        session_id (str): 会话的唯一标识符
    
    返回:
        BaseChatMessageHistory: 对应会话的聊天历史对象
    """
    if session_id not in store:
        # 如果会话ID不存在于存储中，创建一个新的内存聊天历史实例
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# %% [markdown]
# #Agent 核心技术：Prompt 设计
# #使用GPT生成提示词：
#
# 优化下面的大模型 Prompt：
#
# 你是一个英语老师，你擅长循循善诱的教导不同水平的学生。
#
# 你的教学方式是通过对话式训练英语技能，为此，你设计了几种特定场景对话：技术面试、饭店点餐、会议主持等。
#
# 针对这几个场景，详细设计场景中的对话流程，每个场景至少包括10轮对话，并引导学生回答道流程中

# %%
#经过若干次调整后

# %% [markdown]
# 提示词：
#
# You are a patient and encouraging English teacher, skilled in tailoring lessons to students of different proficiency levels (beginner, intermediate, advanced).
#
# Your task is to provide conversation-based training to help students improve their English speaking and listening skills. For each scenario listed below, design a dialogue with at least 10 turns. You will ask questions and guide the student to provide appropriate responses, correcting them when necessary and offering feedback. The conversation scenarios include:
#
# Technical Interview: Simulate a typical technical interview covering personal introductions, technical questions, and behavioral interview questions.
# Restaurant Ordering: Simulate ordering at a restaurant, including asking about the menu, placing an order, making special requests, and paying.
# Meeting Hosting: Simulate hosting a meeting, including opening remarks, guiding speakers, managing time, and summarizing the meeting.
# Dialogue Flow:
#
# Start by guiding the student into one of the scenarios.
# If the student asks a general question

# %% [markdown]
# Gradio 是什么？
# Gradio 是一个用于快速创建可分享的机器学习模型界面的开源 Python 库。通过 Gradio，开发者能够轻松地为他们的
# 模型创建前端界面，从而使非技术用户也可以通过简单的网页界面与这些模型进行交互。这样的交互可以包括输入文本、
# 上传图片或音频文件，并查看模型的输出结果。
# Gradio 的一些主要特点包括：
# 1.易用性：Gradio 允许开发者仅用几行代码就能创建出交互式的界面。
# 2.集成：它支持多种机器学习框架，如 TensorFlow、PyTorch 和 Hugging Face Transformers。
# 3.共享和部署：Gradio 应用可以生成一个 URL，通过这个 URL，用户可以远程访问模型的界面，也可以将这些界面嵌
# 入到文章或网站中。
# 4.组件丰富：Gradio 提供多种输入和输出组件（如滑块、下拉菜单、图表等），方便定制丰富的用户交互体验。
# 5.安全性：支持私有部署和安全连接，保护数据和模型的隐私。
# Gradio 非常适合数据科学家和机器学习工程师在初步模型开发和原型设计阶段，快速构建和迭代原型，使团队和利益
# 相关者能够实时测
#
# 项目地址：https://huggingface.co/spaces/stabilityai/stable-diffusion试和反馈模型性能和功能。

# %%
#前端界面设计：与 Gradio 集成
import gradio as gr


def greet(name):
    return "Hello " + name + "!"


demo = gr.Interface(fn=greet, inputs="textbox", outputs="textbox")

if __name__ == "__main__":
    demo.launch()
